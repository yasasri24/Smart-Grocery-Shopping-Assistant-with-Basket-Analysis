# %%
import numpy as np
import pandas as pd

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
basket_df = pd.read_csv('/content/drive/MyDrive/basket.csv')
basket_df
# Out:
#                            0                   1                    2       3  \
# 0                 whole milk              pastry          salty snack     NaN
# 1                    sausage          whole milk  semi-finished bread  yogurt
# 2                       soda  pickled vegetables                  NaN     NaN
# 3                canned beer     misc. beverages                  NaN     NaN
# 4                    sausage    hygiene articles                  NaN     NaN
# ...                      ...                 ...                  ...     ...
# 14958            butter milk  whipped/sour cream                  NaN     NaN
# 14959          bottled water               herbs                  NaN     NaN
# 14960  fruit/vegetable juice              onions                  NaN     NaN
# 14961           bottled beer    other vegetables                  NaN     NaN
# 14962                   soda     root vegetables  semi-finished bread     NaN
#
# ...

# %%
basket_df.fillna('NA', inplace=True)
basket_df

basket_df_list = basket_df.values.tolist()

# Removing 'NA' from each list
for i in range(len(basket_df_list)):
    basket_df_list[i] = [x for x in basket_df_list[i] if not x=='NA']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()
te_ary = te.fit(basket_df_list).transform(basket_df_list)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apriori Algorithm

frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)

frequent_itemsets.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                 itemsets
# 0  0.004010  (Instant food products)
# 1  0.021386               (UHT-milk)
# 2  0.001470       (abrasive cleaner)
# 3  0.001938       (artif. sweetener)
# 4  0.008087          (baking powder)
# 5  0.001136       (bathroom cleaner)
# 6  0.033950                   (beef)
# 7  0.021787                (berries)
# 8  0.016574              (beverages)
# 9  0.045312           (bottled beer)

# %%
r1=rules.sort_values(by='confidence', ascending=False).head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def recommend_items(items, rules):
    recommended_items = set()
    for item in items:
        recommendations = rules[rules['antecedents'] == {item}]['consequents']
        recommended_items.update(recommendations)
    return recommended_items

# Example usage:
items = ['oil']
recommendations = recommend_items(items, rules)
s=''
for i in recommendations:
  s+=str(i)
print(type(recommendations))
print("Recommended items:", list(recommendations),s)
# Out:
# <class 'set'>
# Recommended items: [frozenset({'soda'}), frozenset({'whole milk'}), frozenset({'other vegetables'})] frozenset({'soda'})frozenset({'whole milk'})frozenset({'other vegetables'})
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules.to_hdf('data.h5', key='df', mode='w')
df = pd.read_hdf('data.h5', key='df')
len(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-6-3b1d61680e5a>:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['antecedents', 'consequents'], dtype='object')]
#
#   rules.to_hdf('data.h5', key='df', mode='w')
# 130

# %%
def recommend_items(items, rules):
    recommended_items = set()
    for item in items:
        recommendations = rules[rules['antecedents'] == {item}]['consequents']
        recommended_items.update(recommendations)
    return recommended_items

# Example usage:
items = ['oil']
recommendations = recommend_items(items, df)
s=''
for i in recommendations:
  s+=str(i)
print(type(recommendations))
print("Recommended items:", list(recommendations),s)
# Out:
# <class 'set'>
# Recommended items: [frozenset({'soda'}), frozenset({'whole milk'}), frozenset({'other vegetables'})] frozenset({'soda'})frozenset({'whole milk'})frozenset({'other vegetables'})
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# rules.to_csv('r1.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# r2=rules.sort_values(by='lift', ascending=False).head(20)
# r2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pd.__version__
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '1.5.3'

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
